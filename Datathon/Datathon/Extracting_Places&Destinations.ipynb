# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("Visitors Preference Dataset.csv")

# %%
data.head()
# Out:
#    User ID              Name                         Email  \
# 0        1    Jennifer Quinn    jennifer.quinn@example.com
# 1        2       Emily Perry       emily.perry@example.com
# 2        3  Danielle Mcbride  danielle.mcbride@example.com
# 3        4   Angelica Wilson   angelica.wilson@example.com
# 4        5     Laurie Powers     laurie.powers@example.com
#
#                                 Preferred Activities  \
# 0  ['cycling', 'historical monuments', 'village h...
# 1  ['butterfly watching', 'hot springs', 'wildlif...
# 2  ['sea cruises', 'themed parks', 'craft worksho...
# 3              ['fishing', 'hot springs', 'sailing']
# 4     ['history tours', 'sailing', 'literary tours']
#
#                   Bucket list destinations Sri Lanka
# 0  ['Polonnaruwa', 'Hatton', 'Anuradhapura', 'Ell...
# 1  ['Madunagala Hot Water Spring', 'Wilpattu Nati...
# 2  ['Mirissa Beach', 'Negombo Lagoon', 'Batadomba...
# 3  ['Maha Oya Hot Water Springs', 'Colombo Port C...
# ...

# %%
data.tail()
# Out:
#       User ID                Name                           Email  \
# 9995     9996  Jonathan Hernandez  jonathan.hernandez@example.com
# 9996     9997       Cody Gallegos       cody.gallegos@example.com
# 9997     9998           Amy House           amy.house@example.com
# 9998     9999      Leslie Aguilar      leslie.aguilar@example.com
# 9999    10000        Joseph Stone        joseph.stone@example.com
#
#                                    Preferred Activities  \
# 9995    ['paddleboarding', 'river cruises', 'kayaking']
# 9996       ['theater', 'scuba diving', 'yoga retreats']
# 9997  ['sea cruises', 'zip-lining', 'outdoor adventu...
# 9998   ['cycling', 'amusement parks', 'paddleboarding']
# 9999                   ['camping', 'hiking', 'safaris']
#
#                      Bucket list destinations Sri Lanka
# 9995  ['Ahungalla', 'Bolgoda Lake', 'Unawatuna Beach...
# 9996  ['Kalpitiya', 'Hikkaduwa Coral Sanctuary', 'Tr...
# 9997  ['Hikkaduwa Coral Sanctuary', 'Ella', 'Pigeon ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   User ID                             10000 non-null  int64
#  1   Name                                10000 non-null  object
#  2   Email                               10000 non-null  object
#  3   Preferred Activities                10000 non-null  object
#  4   Bucket list destinations Sri Lanka  10000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 390.8+ KB

# %%
data.nunique()
# Out:
# User ID                               10000
# Name                                   9419
# Email                                  9369
# Preferred Activities                   9830
# Bucket list destinations Sri Lanka     9995
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# User ID                               0.0
# Name                                  0.0
# Email                                 0.0
# Preferred Activities                  0.0
# Bucket list destinations Sri Lanka    0.0
# dtype: float64

# %%
data = data.drop(['Email'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   User ID                             10000 non-null  int64
#  1   Name                                10000 non-null  object
#  2   Preferred Activities                10000 non-null  object
#  3   Bucket list destinations Sri Lanka  10000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB

# %%
data = data.drop(['User ID'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Name                                10000 non-null  object
#  1   Preferred Activities                10000 non-null  object
#  2   Bucket list destinations Sri Lanka  10000 non-null  object
# dtypes: object(3)
# memory usage: 234.5+ KB

# %%
data.head()
# Out:
#                Name                               Preferred Activities  \
# 0    Jennifer Quinn  ['cycling', 'historical monuments', 'village h...
# 1       Emily Perry  ['butterfly watching', 'hot springs', 'wildlif...
# 2  Danielle Mcbride  ['sea cruises', 'themed parks', 'craft worksho...
# 3   Angelica Wilson              ['fishing', 'hot springs', 'sailing']
# 4     Laurie Powers     ['history tours', 'sailing', 'literary tours']
#
#                   Bucket list destinations Sri Lanka
# 0  ['Polonnaruwa', 'Hatton', 'Anuradhapura', 'Ell...
# 1  ['Madunagala Hot Water Spring', 'Wilpattu Nati...
# 2  ['Mirissa Beach', 'Negombo Lagoon', 'Batadomba...
# 3  ['Maha Oya Hot Water Springs', 'Colombo Port C...
# 4  ['Negombo Lagoon', 'Colombo Port City', 'Galle...

# %%
duplicate_responses = data[data.duplicated(subset=['Name'])]
duplicate_responses
# Out:
#                     Name                               Preferred Activities  \
# 303   Christopher Garcia              ['tea tasting', 'golfing', 'fishing']
# 401          James White  ['architecture photography', 'golfing', 'craft...
# 410           Eric Myers  ['historical monuments', 'amusement parks', 's...
# 587          John Wright  ['whale watching', 'historic walks', 'elephant...
# 619           Mary Jones           ['caving', 'tea tasting', 'sightseeing']
# ...                  ...                                                ...
# 9931   Andrea Williamson  ['architecture photography', 'public art insta...
# 9942   Michael Rodriguez   ['craft workshops', 'whale watching', 'surfing']
# 9957      Samantha Smith      ['amusement parks', 'horse shows', 'safaris']
# 9986      David Williams  ['architecture photography', 'botanical garden...
# 9989    Christina Farley  ['outdoor adventures', 'village homestays', 'h...
#
#                      Bucket list destinations Sri Lanka
# ...

# %%
data_unique = data.drop_duplicates(subset=['Name'], keep='last')
data_unique
# Out:
#                     Name                               Preferred Activities  \
# 0         Jennifer Quinn  ['cycling', 'historical monuments', 'village h...
# 1            Emily Perry  ['butterfly watching', 'hot springs', 'wildlif...
# 2       Danielle Mcbride  ['sea cruises', 'themed parks', 'craft worksho...
# 3        Angelica Wilson              ['fishing', 'hot springs', 'sailing']
# 4          Laurie Powers     ['history tours', 'sailing', 'literary tours']
# ...                  ...                                                ...
# 9995  Jonathan Hernandez    ['paddleboarding', 'river cruises', 'kayaking']
# 9996       Cody Gallegos       ['theater', 'scuba diving', 'yoga retreats']
# 9997           Amy House  ['sea cruises', 'zip-lining', 'outdoor adventu...
# 9998      Leslie Aguilar   ['cycling', 'amusement parks', 'paddleboarding']
# 9999        Joseph Stone                   ['camping', 'hiking', 'safaris']
#
#                      Bucket list destinations Sri Lanka
# ...

# %%
PA=data[['Preferred Activities']]
PA
# Out:
#                                    Preferred Activities
# 0     ['cycling', 'historical monuments', 'village h...
# 1     ['butterfly watching', 'hot springs', 'wildlif...
# 2     ['sea cruises', 'themed parks', 'craft worksho...
# 3                 ['fishing', 'hot springs', 'sailing']
# 4        ['history tours', 'sailing', 'literary tours']
# ...                                                 ...
# 9995    ['paddleboarding', 'river cruises', 'kayaking']
# 9996       ['theater', 'scuba diving', 'yoga retreats']
# 9997  ['sea cruises', 'zip-lining', 'outdoor adventu...
# 9998   ['cycling', 'amusement parks', 'paddleboarding']
# 9999                   ['camping', 'hiking', 'safaris']
#
# [10000 rows x 1 columns]

# %%
data['Preferred Activities'].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 9995    <class 'str'>
# 9996    <class 'str'>
# 9997    <class 'str'>
# 9998    <class 'str'>
# 9999    <class 'str'>
# Name: Preferred Activities, Length: 10000, dtype: object

# %%
data['Preferred Activities'].apply(type).value_counts()
# Out:
# Preferred Activities
# <class 'str'>    10000
# Name: count, dtype: int64

# %%
data['Preferred Activities'] = data['Preferred Activities'].apply(eval)

# %%
data['Preferred Activities'].apply(type)
# Out:
# 0       <class 'list'>
# 1       <class 'list'>
# 2       <class 'list'>
# 3       <class 'list'>
# 4       <class 'list'>
#              ...
# 9995    <class 'list'>
# 9996    <class 'list'>
# 9997    <class 'list'>
# 9998    <class 'list'>
# 9999    <class 'list'>
# Name: Preferred Activities, Length: 10000, dtype: object

# %%
activities = sum(data['Preferred Activities'].tolist(), [])
len(activities)
# Out:
# 30000

# %%
activities = list(set(activities))
len(activities)
# Out:
# 68

# %%
activities
# Out:
# ['beach visits',
#  'boat safaris',
#  'traditional ceremonies',
#  'history tours',
#  'cultural festivals',
#  'mountain biking',
#  'village homestays',
#  'snorkeling',
#  'hot springs',
#  'outdoor adventures',
#  'horse shows',
#  'surfing',
#  'arts and culture',
#  'local crafts',
#  'archaeological sites',
#  'animal encounters',
#  'turtle watching',
#  'hiking',
#  'museum visits',
#  'yoga retreats',
#  'tea tasting',
#  'butterfly watching',
#  'botanical gardens',
#  'caving',
#  'photography',
#  'bird watching',
#  'city tours',
#  'craft workshops',
#  'cycling',
#  'kayaking',
#  'literary tours',
#  'beachfront dining',
#  'temple pilgrimages',
#  'golfing',
#  'elephant rides',
#  'sailing lessons',
#  'planetarium visits',
#  'safaris',
#  'art classes',
#  'architecture photography',
#  'ayurvedic spa treatments',
#  'theater',
#  'scuba diving',
#  'rock climbing',
#  'amusement parks',
#  'paddleboarding',
#  'waterfalls',
#  'water parks',
#  'camping',
# ...

# %%
PD=data[['Bucket list destinations Sri Lanka']]
PD
# Out:
#                      Bucket list destinations Sri Lanka
# 0     ['Polonnaruwa', 'Hatton', 'Anuradhapura', 'Ell...
# 1     ['Madunagala Hot Water Spring', 'Wilpattu Nati...
# 2     ['Mirissa Beach', 'Negombo Lagoon', 'Batadomba...
# 3     ['Maha Oya Hot Water Springs', 'Colombo Port C...
# 4     ['Negombo Lagoon', 'Colombo Port City', 'Galle...
# ...                                                 ...
# 9995  ['Ahungalla', 'Bolgoda Lake', 'Unawatuna Beach...
# 9996  ['Kalpitiya', 'Hikkaduwa Coral Sanctuary', 'Tr...
# 9997  ['Hikkaduwa Coral Sanctuary', 'Ella', 'Pigeon ...
# 9998  ['Ella', 'Hatton', 'Negambo', 'Colombo Port Ci...
# 9999  ['Kitugala Forest', 'Wilpattu National Park', ...
#
# [10000 rows x 1 columns]

# %%
data['Bucket list destinations Sri Lanka'].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 9995    <class 'str'>
# 9996    <class 'str'>
# 9997    <class 'str'>
# 9998    <class 'str'>
# 9999    <class 'str'>
# Name: Bucket list destinations Sri Lanka, Length: 10000, dtype: object

# %%
data['Bucket list destinations Sri Lanka'].apply(type).value_counts()
# Out:
# Bucket list destinations Sri Lanka
# <class 'str'>    10000
# Name: count, dtype: int64

# %%
data['Bucket list destinations Sri Lanka'] = data['Bucket list destinations Sri Lanka'].apply(eval)

# %%
all_activities = sum(data['Preferred Activities'].tolist(), [])

# %%
data['Bucket list destinations Sri Lanka'].apply(type).value_counts()
# Out:
# Bucket list destinations Sri Lanka
# <class 'list'>    10000
# Name: count, dtype: int64

# %%
destinations = sum(data['Bucket list destinations Sri Lanka'].tolist(), [])
len(destinations)
# Out:
# 49988

# %%
destinations = list(set(destinations))
len(destinations)
# Out:
# 157

# %%
destinations
# Out:
# ['Colombo Port City',
#  'Kandy Temple',
#  'Nelum Pokuna Theatre',
#  'Anuradapura',
#  'Bentota River',
#  "Baker's Falls",
#  'Elephant Transit Home',
#  'Velgam Vehera Buddhist Temple',
#  'Ahungalla',
#  'Udawalawe',
#  'Victoria Golf Club',
#  'National Gallery of Art',
#  'Uppuveli Beach',
#  'Kithulgala',
#  'Bundala National Park',
#  'Ella Gap',
#  'Sri Lanka Planetarium',
#  'Pigeon Island',
#  'Water World Lanka',
#  'Wilpattu National Park',
#  'Mahapelessa Hot Springs',
#  'Hikkaduwa Beach',
#  'Udawalawe National Park',
#  'Excel World',
#  'Knuckles',
#  'Ella Rock',
#  'Jungle beach',
#  ' Laxapana Falls',
#  'Horton Plains',
#  'Ella',
#  'Sigiriya',
#  'Kosgoda Turtle Hatchery',
#  'Minneriya National Park',
#  'Museum of Modern and Contemporary Art',
#  'Yala National Park',
#  'Negombo',
#  'Bentota Beach',
#  'Wasgamuwa National Park',
#  'Dry Zone Botanic Gardens, Hambantota',
#  'Trincomalee',
#  'Galle Fort',
#  'Sinharaja Forest Reserve',
# ...

# %%
activities = ['beach visits',
 'boat safaris',
 'traditional ceremonies',
 'history tours',
 'cultural festivals',
 'mountain biking',
 'village homestays',
 'snorkeling',
 'hot springs',
 'outdoor adventures',
 'horse shows',
 'surfing',
 'arts and culture',
 'local crafts',
 'archaeological sites',
 'animal encounters',
 'turtle watching',
 'hiking',
 'museum visits',
 'yoga retreats',
 'tea tasting',
 'butterfly watching',
 'botanical gardens',
 'caving',
 'photography',
 'bird watching',
 'city tours',
 'craft workshops',
 'cycling',
 'kayaking',
 'literary tours',
 'beachfront dining',
 'temple pilgrimages',
 'golfing',
 'elephant rides',
 'sailing lessons',
 'planetarium visits',
 'safaris',
 'art classes',
 'architecture photography',
 'ayurvedic spa treatments',
 'theater',
 'scuba diving',
 'rock climbing',
 'amusement parks',
 'paddleboarding',
 'waterfalls',
 'water parks',
 'camping',
 'wildlife viewing',
 'sailing',
 'historic sites',
 'sea cruises',
 'landscape photography',
 'river cruises',
 'cultural experiences',
 'fishing',
 'themed parks',
 'historic walks',
 'whale watching',
 'architecture tours',
 'hot air ballooning',
 'spiritual retreats',
 'sightseeing',
 'zip-lining',
 'horseback riding',
 'historical monuments',
 'public art installations']

# %%
activities_sorted = sorted(activities)

print(activities_sorted)
# Out:
# ['amusement parks', 'animal encounters', 'archaeological sites', 'architecture photography', 'architecture tours', 'art classes', 'arts and culture', 'ayurvedic spa treatments', 'beach visits', 'beachfront dining', 'bird watching', 'boat safaris', 'botanical gardens', 'butterfly watching', 'camping', 'caving', 'city tours', 'craft workshops', 'cultural experiences', 'cultural festivals', 'cycling', 'elephant rides', 'fishing', 'golfing', 'hiking', 'historic sites', 'historic walks', 'historical monuments', 'history tours', 'horse shows', 'horseback riding', 'hot air ballooning', 'hot springs', 'kayaking', 'landscape photography', 'literary tours', 'local crafts', 'mountain biking', 'museum visits', 'outdoor adventures', 'paddleboarding', 'photography', 'planetarium visits', 'public art installations', 'river cruises', 'rock climbing', 'safaris', 'sailing', 'sailing lessons', 'scuba diving', 'sea cruises', 'sightseeing', 'snorkeling', 'spiritual retreats', 'surfing', 'tea tasting', 't
# ...

# %%
activities_sorted
# Out:
# ['amusement parks',
#  'animal encounters',
#  'archaeological sites',
#  'architecture photography',
#  'architecture tours',
#  'art classes',
#  'arts and culture',
#  'ayurvedic spa treatments',
#  'beach visits',
#  'beachfront dining',
#  'bird watching',
#  'boat safaris',
#  'botanical gardens',
#  'butterfly watching',
#  'camping',
#  'caving',
#  'city tours',
#  'craft workshops',
#  'cultural experiences',
#  'cultural festivals',
#  'cycling',
#  'elephant rides',
#  'fishing',
#  'golfing',
#  'hiking',
#  'historic sites',
#  'historic walks',
#  'historical monuments',
#  'history tours',
#  'horse shows',
#  'horseback riding',
#  'hot air ballooning',
#  'hot springs',
#  'kayaking',
#  'landscape photography',
#  'literary tours',
#  'local crafts',
#  'mountain biking',
#  'museum visits',
#  'outdoor adventures',
#  'paddleboarding',
#  'photography',
#  'planetarium visits',
#  'public art installations',
#  'river cruises',
#  'rock climbing',
#  'safaris',
# ...

# %%
print(len(activities_sorted))
# Out:
# 68

# %%
destinations = ['Jaffna Public Library',
 'Sinharaja Forest Reserve',
 'Tangalle',
 ' Laxapana Falls',
 'Ahangama',
 'Pearl Bay',
 'Colombo National Museum',
 'Jaya Sri Maha Bodhi',
 'Mirissa Beach',
 'Sigiriya',
 'Seetha Eliya',
 'Kithulgala',
 'Hakgala Botanical Garden',
 'Trincomalee',
 'Pinnawala Elephant Orphanage',
 'Rekawa Beach',
 'Kumana National Park',
 'Bentota River',
 'Nelum Pokuna Theatre',
 'Yala National Park',
 'Mihintale',
 'Elephant Transit Home',
 'Minneriya National Park',
 'Kandy City Centre',
 'Lionel Wendt Art Centre',
 'Ella Rock',
 'Kandy Temple',
 'Horton Plains',
 'Dunhinda Waterfall',
 "St Clair's Falls",
 'Marakolliya Beach',
 'Yapahuwa Rock Fortress',
 'Polonnaruwa',
 'Museum of Modern and Contemporary Art',
 'Haputale',
 'Hikkaduwa',
 'Batadombalena Craft Centre',
 'Madunagala Hot Water Spring',
 'Pidurangala Rock',
 'Viharamahadevi Park',
 'Ruhunu Maha Kataragama Dewalaya',
 'Sri Lanka Planetarium',
 'Nine Arches Bridge',
 'Galle Fort',
 'Ambalangoda',
 'Madu River',
 'Martin Wickramasinghe Folk Museum',
 'Wilpattu National Park',
 'Royal Botanical Gardens, Peradeniya',
 'Kandy Lake',
 'Negombo Lagoon',
 'Vaddha Village Camping',
 "Baker's Falls",
 'Ratnapura Gem Museum',
 'Ella Gap',
 'Hatton',
 'Dry Zone Botanic Gardens, Hambantota',
 'Ambalangoda Mask Workshop',
 'Ella',
 'Ambuluwawa Tower',
 'Jungle beach',
 'Galle City Tour',
 'Anuradhapura',
 'Nallur Kandaswamy Devasthanam',
 'National Gallery of Art',
 'Kosgoda Turtle Hatchery',
 'Bundala National Park',
 'Mahapelessa Hot Springs',
 'Belilena Caves',
 'Excel World',
 'Galle Dutch Fort',
 'Udawalawe',
 'Polonaruwa',
 'Unawatuna Beach',
 'Galle',
 'Perl Bay',
 'Bambarakanda Falls',
 'Ahungalla',
 'Bolgoda Lake',
 'Bambarakiri Ella',
 'Seethawaka Wet Zone Botanical Gardens',
 'Ramboda Falls',
 'Pinnawala',
 'Colombo Port City',
 'Colombo City Tour',
 'Uppuveli Beach',
 'Kandy',
 'Udawalawe National Park',
 'Diyaluma Falls',
 'Riverstone Gap',
 'Passikuda Beach',
 'Knuckles',
 'Devon Falls',
 "Sri Pada / Adam's Peak",
 'Bentota',
 'Horton Plains National Park',
 'Unawatuna',
 'Hikkaduwa Beach',
 'Velgam Vehera Buddhist Temple',
 'Koggala Beach',
 'Dambulla',
 'Bentota Beach',
 'Wavulpone Cave',
 'Weligama Beach',
 'Victoria Golf Club',
 'Negambo',
 'Colombo',
 'Folk Museum',
 'Maritime Museum',
 'Arugam Bay Beach',
 'Nelung Arts Centre',
 'Belihuloya',
 'Water World Lanka',
 'Anuradapura',
 'Batatotalena (Batadombalena) Cave',
 'Dutch Museum',
 'Negombo',
 'Hiriketiya Beach',
 'Galle Lighthouse',
 'Dambulla Royal Cave Temple and Golden Temple',
 'Wasgamuwa National Park',
 'Kalpitiya Lagoon',
 'Nilaveli Beach',
 'Gangaramaya Temple',
 'Trincomalee Harbour',
 'Meemure',
 'Kitugala Forest',
 'Anawilundawa Wetlands',
 'Jungle Beach',
 'Kitulgala',
 'Royal Colombo Golf Club',
 'Weligama Beach (surf and stay)',
 'Unawatuna Lagoon',
 'Arankelle Forest Monastery',
 'Maha Oya Hot Water Springs',
 'Leisure World',
 'National Museum Galle',
 'Kandalama',
 'Pigeon Island',
 'Kanneliya National Rain Forest Reserve',
 'Kandy National Museum',
 'Ravan Ella Waterfall',
 'Hiriketiya',
 'Surathali Ella',
 'Kanniya Hot Springs',
 'Nallur Kandaswamy Kovil',
 'Nuwara Eliya Golf Club',
 'Sri Dalada Maligawa',
 'Ritigala',
 'Bomburu Ella Waterfall',
 'Tangalle Beach',
 'Hikkaduwa Coral Sanctuary',
 'Bopath Falls',
 'Kalpitiya',
 'Nuwara Eliya',
 'Polonnaruwa Ancient City',
 'Mahalenama Cave']

# %%
destinations_sorted = sorted(destinations)
destinations_sorted
# Out:
# [' Laxapana Falls',
#  'Ahangama',
#  'Ahungalla',
#  'Ambalangoda',
#  'Ambalangoda Mask Workshop',
#  'Ambuluwawa Tower',
#  'Anawilundawa Wetlands',
#  'Anuradapura',
#  'Anuradhapura',
#  'Arankelle Forest Monastery',
#  'Arugam Bay Beach',
#  "Baker's Falls",
#  'Bambarakanda Falls',
#  'Bambarakiri Ella',
#  'Batadombalena Craft Centre',
#  'Batatotalena (Batadombalena) Cave',
#  'Belihuloya',
#  'Belilena Caves',
#  'Bentota',
#  'Bentota Beach',
#  'Bentota River',
#  'Bolgoda Lake',
#  'Bomburu Ella Waterfall',
#  'Bopath Falls',
#  'Bundala National Park',
#  'Colombo',
#  'Colombo City Tour',
#  'Colombo National Museum',
#  'Colombo Port City',
#  'Dambulla',
#  'Dambulla Royal Cave Temple and Golden Temple',
#  'Devon Falls',
#  'Diyaluma Falls',
#  'Dry Zone Botanic Gardens, Hambantota',
#  'Dunhinda Waterfall',
#  'Dutch Museum',
#  'Elephant Transit Home',
#  'Ella',
#  'Ella Gap',
#  'Ella Rock',
#  'Excel World',
#  'Folk Museum',
#  'Galle',
#  'Galle City Tour',
# ...

# %%
print(len(destinations_sorted))
# Out:
# 157
